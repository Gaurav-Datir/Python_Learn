# %%
f = open("pomes.txt","r")

# %%
content = f.read()

# %%
if ("twinkle" in content):
    print("the twinkel Word is present")
else:
     print("the twinkel Word not is present")
# Out:
# the twinkel Word is present

# %%
f.close()
